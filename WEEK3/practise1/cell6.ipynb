# %%
def printinfo(name, age=30):
    print("Name :", name);
    print("Age:", age);
    return;
printinfo(age=50, name="miki" );
printinfo( name="miki");
# Out:
# Name : miki
# Age: 50
# Name : miki
# Age: 30
