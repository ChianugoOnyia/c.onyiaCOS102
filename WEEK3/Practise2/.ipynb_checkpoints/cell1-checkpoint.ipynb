# %%
import tkinter as tk

def button_click():

    msgbox.showinfo("info", "Welcome to COS102 Gui app!\n")
    result = mdgbox.askyesno("Confirmation", "Do you want to continue?")

root = tk.Tk()
root.title("Home page")
root.geometry("300x100")

label = tk.Label(root, text="Hello Friend \n")
label.pack()

button = tk.Button(root, text="Click me!", command=button_click)
button.pack()

button.config(fg="red", bg="yellow")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 12
#       9 root.title("Home page")
#      10 root.geometry("300x100")
# ---> 12 label = tk.label(root, text="Hello Friend \n")
#      13 label.pack()
#      15 button = tk.Button(root, text="Click me!", command=button_click)
#
# AttributeError: module 'tkinter' has no attribute 'label'
