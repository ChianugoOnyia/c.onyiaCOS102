# %%
P = 10000      
R = 5          
T = 3

simple = P * (1 + (R / 100) * T)
print("Simple Interest Amount =", round(simple,2))

       

compound = P * (1 + (R / 100)) ** T
print("Compound Interest Amount =", round(compound,2))

PMT = 2000     
 


annuity = PMT * ((((1 + R/100) ** T) - 1) / R)
print("Annuity Amount =", round(annuity,2))
# Out:
# Simple Interest Amount = 11500.0
# Compound Interest Amount = 11576.25
# Annuity Amount = 63.05
