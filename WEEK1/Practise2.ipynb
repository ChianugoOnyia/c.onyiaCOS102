# %%
str1 = "Hi my name is Onyia. I am String"
str2 = "Hi my name is Precious. I am also a String"


print(str1)
print(type(str1))


print(str2)
print(type(str2))
# Out:
# Hi my name is Onyia. I am String
# <class 'str'>
# Hi my name is Precious. I am also a String
# <class 'str'>
