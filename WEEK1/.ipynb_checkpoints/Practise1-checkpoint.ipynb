# %%
num = 100
print(num)
# Out:
# 100

# %%
print("Data type of variable num is",type(num))
# Out:
# Data type of variable num is <class 'int'>

# %%
fnum = 34.45
print(fnum)
print("Dta type of variable fnum is",type(fnum))
# Out:
# 34.45
# Dta type of variable fnum is <class 'float'>
