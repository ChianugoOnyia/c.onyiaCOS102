# %%
print("Choose the equation you want to work with:")
print("1 - Quadratic Equation")
print("2 - Cubic Equation")
print("3 - Quartic Equation")

choice = input("Enter your choice: ")

if choice == "1":
    print("You chose a Quadratic Equation")

elif choice == "2":
    print("You chose a Cubic Equation")

elif choice == "3":
    print("You chose a Quartic Equation")

else:
    print("Invalid choice")
# Out:
# Choose the equation you want to work with:
# 1 - Quadratic Equation
# 2 - Cubic Equation
# 3 - Quartic Equation
