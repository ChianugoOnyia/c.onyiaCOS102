# %% [markdown]
# ![Flowchart](project1B-flowchart.png)

# %% [markdown]
# START
# ALARM rings
# WAKE up
# CHECK messages
# BRUSH teeth
# SHOWER
# CHECK timetable
# IF I have cLass today
#     GET ready For school
#     GO to SST BUILDING
#     GO to classs
# ELSE
#     GO back to sleep
# END IF
# END
