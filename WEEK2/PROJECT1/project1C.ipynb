# %%
NAME_1 = input('Enter name1: ')
AGE_1 = int(input('Enter age: '))
NAME_2 = input('Enter name2: ')
AGE_2 = int(input('Enter age: '))


temp = AGE_1
AGE_1 = AGE_2
AGE_2 = temp

print(f"The age of {NAME_1} is {AGE_1}")
print(f"The age of {NAME_2} is {temp}")
# Out:
# Enter name1:  sd
# Enter age:  24
# Enter name2:  34
# Enter age:  df
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 AGE_1 = int(input('Enter age: '))
#       3 NAME_2 = input('Enter name2: ')
# ----> 4 AGE_2 = int(input('Enter age: '))
#       7 temp = AGE_1
#       8 AGE_1 = AGE_2
#
# ValueError: invalid literal for int() with base 10: 'df'
