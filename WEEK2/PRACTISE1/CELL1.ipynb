# %%
str = input("Enter your state or origin:")

print ("Your state of origin is: ",str)
print ("The first charcter is: ",str[0])
print ("The characters startng from 3rd to 5th are:",str[2:5])
print ("State of origin two times", str*2)
# Out:
# Enter your state or origin: enugu
# Your state of origin is:  enugu
# The first charcter is:  e
# The characters startng from 3rd to 5th are: ugu
# State of origin two times enuguenugu
