# %%
m = float(input("Enter mass in kilogram:"))
c=299792458
energy = m*c **2
print(f"The energy equivalent to {m} kg of mass is {energy} joules.")
# Out:
# Enter mass in kilogram: 23
# The energy equivalent to 23.0 kg of mass is 2.0671369110946806e+18 joules.
