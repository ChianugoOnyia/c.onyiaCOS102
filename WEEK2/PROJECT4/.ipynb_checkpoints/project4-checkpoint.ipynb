# %%
age = int(input("Enter staff age: "))
experience = int(input("Enter years of experience: "))


if experience > 25 and age >= 55:
    ATR = 5600000

elif experience > 20 and age >= 45:
    ATR = 4480000

elif experience > 10 and age >= 35:
    ATR = 1500000

elif experience < 10 and age < 35:
    ATR = 550000
elif experience > age :
    print("Experience cannot be greater than age")

else:
    ATR = 0


print("Annual Tax Revenue (ATR): N", ATR)
# Out:
# Enter staff age:  23
# Enter years of experience:  45
# Experience cannot be greater than age
# Annual Tax Revenue (ATR): N 0
